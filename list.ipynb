# %%
list=[2,3,4,5]

# %%
# Add an element to the end of a list.
list.append(6)
list
# Out:
# [2, 3, 4, 5, 6, 6]

# %%
# Insert an element at the beginning of a list.
list[0]=9
list
# Out:
# [9, 3, 4, 5, 6, 6]
